# %%
#import libraries
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error,mean_squared_error, r2_score
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder

# %%
#load the dataset
ds=pd.read_csv('/content/cardata.csv')
print('DataSet loaded successfully');
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_3210/1017070800.py in <cell line: 0>()
#       1 #load the dataset
# ----> 2 ds=pd.read_csv('/content/cardata.csv')
#       3 print('DataSet loaded successfully');
#
# ...

# %%
ds.head()
# Out:
#   Car_Name  Year  Selling_Price  ...  Seller_Type  Transmission Owner
# 0     ritz  2014           3.35  ...       Dealer        Manual     0
# 1      sx4  2013           4.75  ...       Dealer        Manual     0
# 2     ciaz  2017           7.25  ...       Dealer        Manual     0
# 3  wagon r  2011           2.85  ...       Dealer        Manual     0
# 4    swift  2014           4.60  ...       Dealer        Manual     0
#
# [5 rows x 9 columns]

# %%
ds.shape
# Out:
# (301, 9)

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Seller_Type    301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
ds.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
#detecting missing values
ds.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
#count occurance of each fuel_type in the dataset
ds['Fuel_Type'].value_counts()
# Out:
# Fuel_Type
# Petrol    239
# Diesel     60
# CNG         2
# Name: count, dtype: int64

# %%
#count occurance of each Seller_type in the dataset
ds['Seller_Type'].value_counts()
# Out:
# Seller_Type
# Dealer        195
# Individual    106
# Name: count, dtype: int64

# %%
#count occurance of each Transmission in the dataset
ds['Transmission'].value_counts()
# Out:
# Transmission
# Manual       261
# Automatic     40
# Name: count, dtype: int64

# %%
#One hot encoding
ds=pd.get_dummies(ds,columns=['Fuel_Type'])
ds=pd.get_dummies(ds,columns=['Seller_Type'])
ds=pd.get_dummies(ds,columns=['Transmission'])
print(ds.head())
# Out:
#   Car_Name  Year  ...  Transmission_Automatic  Transmission_Manual
# 0     ritz  2014  ...                   False                 True
# 1      sx4  2013  ...                   False                 True
# 2     ciaz  2017  ...                   False                 True
# 3  wagon r  2011  ...                   False                 True
# 4    swift  2014  ...                   False                 True
#
# [5 rows x 13 columns]

# %%
ds.columns
# Out:
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Kms_Driven',
#        'Owner', 'Fuel_Type_CNG', 'Fuel_Type_Diesel', 'Fuel_Type_Petrol',
#        'Seller_Type_Dealer', 'Seller_Type_Individual',
#        'Transmission_Automatic', 'Transmission_Manual'],
#       dtype='object')

# %%
#create feature matrix x by dropping car_name and selling_price columns
X=ds.drop(['Car_Name','Selling_Price'],axis=1)
print("Feature matrix x is created by dropping car_name and selling_price columns")
# Out:
# Feature matrix x is created by dropping car_name and selling_price columns

# %%
# Create target vector Y containing the Selling_Price column
Y = ds['Selling_Price']
print("Target vector Y created from 'Selling_Price' column.")
# Out:
# Target vector Y created from 'Selling_Price' column.

# %%
X.head()
# Out:
#    Year  Present_Price  ...  Transmission_Automatic  Transmission_Manual
# 0  2014           5.59  ...                   False                 True
# 1  2013           9.54  ...                   False                 True
# 2  2017           9.85  ...                   False                 True
# 3  2011           4.15  ...                   False                 True
# 4  2014           6.87  ...                   False                 True
#
# [5 rows x 11 columns]

# %%
Y.head()
# Out:
# 0    3.35
# 1    4.75
# 2    7.25
# 3    2.85
# 4    4.60
# Name: Selling_Price, dtype: float64

# %%
# Split the dataset into training and testing sets, then train a Linear Regression model
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.20, random_state = 42)
print("DataSet split into training and testing sets")
# Out:
# DataSet split into training and testing sets

# %%
#Create the model
model = LinearRegression()
print("Linear Regression Model Created Successfully")
# Out:
# Model Created Successfully

# %%
#Train the model
model.fit(X_train, Y_train)
print("Model Trained on the training data ")
# Out:
# Model Trained on the training data

# %%
#Generate predictions for training and testing data
Y_train_pred = model.predict(X_train)
Y_test_pred = model.predict(X_test)
print("Predictions generated for training and testing data")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3210/2926077372.py in <cell line: 0>()
#       1 #Generate predictions for training and testing data
# ----> 2 Y_train_pred = model.predict(X_train)
#       3 Y_test_pred = model.predict(X_test)
#       4 print("Predictions generated for training and testing data")
#
# NameError: name 'model' is not defined

# %%
#Evaluate the model performance on training and testing data using metrics
mae_train = mean_absolute_error(Y_train, Y_train_pred)
mse_train = mean_squared_error(Y_train, Y_train_pred)
r2_train = r2_score(Y_train, Y_train_pred)
root_mse_train = np.sqrt(mse_train)
print("Model Performance on Training Data:")
print("Mean Absolute Error (MAE):", mae_train)
print("Mean Squared Error (MSE):", mse_train)
print("Root Mean Squared Error (RMSE):", root_mse_train)
print("R-squared (R2) Score:", r2_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3210/4098814580.py in <cell line: 0>()
#       1 #Evaluate the model performance on training and testing data using metrics
# ----> 2 mae_train = mean_absolute_error(Y_train, Y_train_pred)
#       3 mse_train = mean_squared_error(Y_train, Y_train_pred)
#       4 r2_train = r2_score(Y_train, Y_train_pred)
#       5 root_mse_train = np.sqrt(mse_train)
#
# NameError: name 'mean_absolute_error' is not defined

# %%
#coefficients and Intercepts
print("Coefficients:", model.coef_)
print("Intercept:", model.intercept_)
# Out:
# Coefficients: [ 3.53801365e-01  4.29152503e-01 -6.15725866e-06 -9.03759824e-01
#  -1.09057894e+00  1.44269365e+00 -3.52114710e-01  5.95296453e-01
#  -5.95296453e-01  8.19510777e-01 -8.19510777e-01]
# Intercept: -710.2771513359723

# %%
# Plot residuals against predicted values on training data to analyze error patterns
residuals = Y_train - Y_train_pred
plt.scatter(Y_train_pred, residuals)
plt.axhline(0, color='red', linestyle='--', linewidth=2)
plt.xlabel("Predicted Price")
plt.ylabel("Residual (Actual - Predicted)")
plt.title("Residual vs Predicted Plot on Train Set")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3210/356415543.py in <cell line: 0>()
#       1 # Plot residuals against predicted values on training data to analyze error patterns
# ----> 2 residuals = Y_train - Y_train_pred
#       3 plt.scatter(Y_train_pred, residuals)
#       4 plt.axhline(0, color='red', linestyle='--', linewidth=2)
#       5 plt.xlabel("Predicted Price")
#
# NameError: name 'Y_train' is not defined

# %%
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# Ensure 'ds' is available and processed for X and Y, as per previous cells.
# Assuming 'ds' is the one-hot encoded dataframe from cell 't6O5bDPleNbO'.
# If 'ds' is not globally defined or accessible, the user might need to re-run preceding cells.

# Re-create feature matrix X by dropping car_name and selling_price columns (from cell aOgQUGyFagJW)
X=ds.drop(['Car_Name','Selling_Price'],axis=1)

# Re-create target vector Y containing the Selling_Price column (from cell b9QgwKxmfYpx)
Y = ds['Selling_Price']

# Split the dataset into training and testing sets (from cell cwQ8P-RCf8Pm)
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.20, random_state = 42)

# Create the Linear Regression model (from cell nF2lM0USf8l2)
model = LinearRegression()

# Train the model on the training data (from cell -zUAYfIKgU1A)
model.fit(X_train, Y_train)

# Generate predictions for training and testing data (from cell 2eJ2twqKgpCf)
Y_train_pred = model.predict(X_train)
Y_test_pred = model.predict(X_test)

# Visualization using scatterplot
plt.scatter(Y_train,Y_train_pred,label='Training Data')
plt.scatter(Y_test,Y_test_pred,label='Testing Data')
plt.xlabel('Actual Price')
plt.ylabel('Predicted Price')
plt.title('Actual vs Predicted Prices')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3210/2474440320.py in <cell line: 0>()
#       1 import matplotlib.pyplot as plt
#       2 #visualization using scatterplot
# ----> 3 plt.scatter(Y_train,Y_train_pred,label='Training Data')
#       4 plt.scatter(Y_test,Y_test_pred,label='Testing Data')
#
# NameError: name 'Y_train' is not defined

# %%
#visualization using scatterplot
plt.scatter(y_train,y_train_pred,label='Training Data')
plt.scatter(y_test,y_test_pred,label='Testing Data')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3210/534892186.py in <cell line: 0>()
#       1 #visualization using scatterplot
# ----> 2 plt.scatter(y_train,y_train_pred,label='Training Data')
#       3 plt.scatter(y_test,y_test_pred,label='Testing Data')
#
# NameError: name 'plt' is not defined
